# %%
import numpy as np
import pandas as pd
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
import pandas_datareader as pdr
key=""

# %%
import pandas as pd
df=pd.read_csv('AAPL.csv')
df.head(10)
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
# 5           5   AAPL  2015-06-03 00:00:00+00:00  130.120  130.940  129.90
# 6           6   AAPL  2015-06-04 00:00:00+00:00  129.360  130.580  128.91
# 7           7   AAPL  2015-06-05 00:00:00+00:00  128.650  129.690  128.36
# 8           8   AAPL  2015-06-08 00:00:00+00:00  127.800  129.210  126.83
# 9           9   AAPL  2015-06-09 00:00:00+00:00  127.420  128.080  125.62
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0 symbol                       date   close     high       low  \
# 1248        1248   AAPL  2020-05-11 00:00:00+00:00  315.01  317.050  307.2400
# 1249        1249   AAPL  2020-05-12 00:00:00+00:00  311.41  319.688  310.9100
# 1250        1250   AAPL  2020-05-13 00:00:00+00:00  307.65  315.950  303.2100
# 1251        1251   AAPL  2020-05-14 00:00:00+00:00  309.54  309.790  301.5300
# 1252        1252   AAPL  2020-05-15 00:00:00+00:00  307.71  307.900  300.2100
# 1253        1253   AAPL  2020-05-18 00:00:00+00:00  314.96  316.500  310.3241
# 1254        1254   AAPL  2020-05-19 00:00:00+00:00  313.14  318.520  313.0100
# 1255        1255   AAPL  2020-05-20 00:00:00+00:00  319.23  319.520  316.2000
# 1256        1256   AAPL  2020-05-21 00:00:00+00:00  316.85  320.890  315.8700
# 1257        1257   AAPL  2020-05-22 00:00:00+00:00  318.89  319.230  315.3500
#
#         open    volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1258 non-null   int64
#  1   symbol       1258 non-null   object
#  2   date         1258 non-null   object
#  3   close        1258 non-null   float64
#  4   high         1258 non-null   float64
#  5   low          1258 non-null   float64
#  6   open         1258 non-null   float64
#  7   volume       1258 non-null   int64
#  8   adjClose     1258 non-null   float64
#  9   adjHigh      1258 non-null   float64
#  10  adjLow       1258 non-null   float64
#  11  adjOpen      1258 non-null   float64
#  12  adjVolume    1258 non-null   int64
#  13  divCash      1258 non-null   float64
#  14  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(3), object(2)
# memory usage: 147.5+ KB

# %%
df1=df.reset_index()['close']
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
df1.shape
# Out:
# (1258,)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Set figure size and general font size
plt.rcParams['figure.figsize'] = (12, 18)
plt.rcParams['font.size'] = 12

numeric_cols = df.select_dtypes(include=['number']).columns
numeric_df = df[numeric_cols]

scaler = MinMaxScaler()

# Fit the scaler to your numeric data and transform it
scaled_df = pd.DataFrame(scaler.fit_transform(numeric_df), columns=numeric_df.columns)

figure, axes = plt.subplots(len(scaled_df.columns), sharex=True, figsize=(12, 18))

for ax, col in zip(axes, scaled_df.columns):
    ax.plot(scaled_df[col], color='black', linewidth=1.5)
    ax.set_title(col, fontsize=14, weight='bold', color='black')
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#888888')
    ax.spines['bottom'].set_color('#888888')
    ax.tick_params(axis='y', colors='#555555')
    ax.axes.xaxis.set_visible(False)

figure.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

plt.plot(df1, label='Predicted Data', color='black', linewidth=2, linestyle='-')

plt.title("Actual Data Visualization", fontsize=18, fontweight='bold', pad=20)

plt.xlabel("Index", fontsize=14, labelpad=10)
plt.ylabel("Value", fontsize=14, labelpad=10)

plt.legend(loc='upper left', fontsize=12, frameon=True, fancybox=True, shadow=True, borderpad=1)

# Add minor ticks for better granularity
plt.minorticks_on()
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=10, length=4)

plt.box(on=True)

plt.show()

# %%
import numpy as np
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.17607447]
#  [0.17495567]
#  [0.16862282]
#  ...
#  [0.96635143]
#  [0.9563033 ]
#  [0.96491598]]

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (817, 441)

# %%
train_data
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        [0.1696994 ],
#        [0.16727181],
#        [0.16794731],
#        [0.16473866],
#        [0.16174111],
#        [0.1581525 ],
#        [0.15654817],
#        [0.16271215],
#        [0.1614878 ],
#        [0.1554927 ],
#        [0.15443722],
#        [0.15730811],
#        [0.15604154],
#        [0.15849025],
#        [0.15308621],
#        [0.15735033],
#        [0.15490163],
#        [0.15946129],
#        [0.15688592],
#        [0.1537195 ],
#        [0.14434687],
#        [0.14812547],
#        [0.15308621],
#        [0.15241071],
#        [0.15055307],
#        [0.14924428],
#        [0.13607194],
#        [0.12551718],
#        [0.13906949],
#        [0.14911762],
#        [0.14890653],
#        [0.15401503],
#        [0.16115005],
#        [0.16583636],
#        [0.17618002],
#        [0.17060711],
#        [0.14725998],
#        [0.14700667],
#        [0.14422021],
#        [0.13691632],
# ...

# %%
test_data
# Out:
# array([[0.52651355],
#        [0.52837119],
#        [0.53119986],
#        [0.53871485],
#        [0.5461454 ],
#        [0.55999324],
#        [0.56864815],
#        [0.57962509],
#        [0.58270708],
#        [0.57641645],
#        [0.56049987],
#        [0.55290045],
#        [0.54036139],
#        [0.5636663 ],
#        [0.55192941],
#        [0.57447437],
#        [0.56362408],
#        [0.53846154],
#        [0.53998142],
#        [0.54053027],
#        [0.54753863],
#        [0.53753272],
#        [0.55074728],
#        [0.55665794],
#        [0.54918517],
#        [0.56831039],
#        [0.5716457 ],
#        [0.57806299],
#        [0.58659124],
#        [0.59837035],
#        [0.58114498],
#        [0.56552394],
#        [0.56332855],
#        [0.57641645],
#        [0.53204425],
#        [0.52398041],
#        [0.55632019],
#        [0.53626615],
#        [0.55648907],
#        [0.55243604],
#        [0.5306088 ],
#        [0.54449886],
#        [0.55015621],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_
#  0.50738833 0.50160432 0.51258127 0.49877565 0.47504855 0.47521743
#  0.46601368 0.45106814 0.40268513 0.41509753 0.42463903 0.42109263
# ...

# %%
print(X_train.shape)
# Out:
# (716, 100)

# %%
print(y_train.shape)
# Out:
# (716,)

# %%
print(X_test.shape)
# Out:
# (340, 100)

# %%
print(ytest.shape)
# Out:
# (340,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam') ####Adaptive Moment Estimation, ###param=trainabale parameters
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 50)             │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 50)             │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# ...

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - loss: 0.0277 - val_loss: 0.0682
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 6.3643e-04 - val_loss: 0.0060
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - loss: 7.0611e-04 - val_loss: 0.0047
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 5.7313e-04 - val_loss: 0.0047
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - loss: 6.1152e-04 - val_loss: 0.0041
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - loss: 5.6681e-04 - val_loss: 0.0040
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 5.5303e-04 - val_loss: 0.0044
# Epoch 11/100
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 141.27426514529967

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 235.71454230996622

# %%
import matplotlib.pyplot as plt

look_back = 100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

train_end = len(train_predict) + look_back
test_start = train_end + (look_back * 2) + 1
test_end = len(df1)

plt.figure(figsize=(12, 8))
ax = plt.gca()

# Set background colors for train and test regions
ax.axvspan(look_back, train_end, facecolor='lightgreen', alpha=0.3, label='Train Region')
ax.axvspan(test_start, test_end, facecolor='lightcoral', alpha=0.3, label='Test Region')

plt.plot(scaler.inverse_transform(df1), label='Actual Data', color='black', linewidth=1.5)
plt.plot(trainPredictPlot, label='Train Predictions', color='green', linestyle='dashed', linewidth=2)
plt.plot(testPredictPlot, label='Test Predictions', color='red', linestyle='dotted', linewidth=2)

# Ensure x-axis covers the entire data range
plt.xlim(0, len(df1))

plt.title('Actual Data vs. Model Predictions', fontsize=16)
plt.xlabel('Time', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.8583551465000423,
#  0.8866418981676942,
#  0.8743139407244789,
#  0.8843198513890065,
#  0.8783669678290975,
#  0.8986321033521913,
#  0.925821160179009,
#  0.9287764924427933,
#  0.9567677108840666,
#  0.9386979650426415,
#  0.933040614709111,
#  0.9495060373216249,
#  0.9642404796082076,
#  0.9551211686228154,
#  0.9598919192772104,
#  0.9663514312251966,
#  0.9624672802499368,
#  0.9229502659799038,
#  0.9598497002448705,
#  0.9879253567508233,
#  0.985941062230854,
#  0.9253145317909315,
#  0.9217259140420504,
#  0.964747107996285,
#  0.9757240564046274,
#  0.9915984125643842,
#  0.9697289538123788,
#  0.9761462467280253,
#  0.9679557544541082,
#  1.0000000000000002,
#  0.9901629654648318,
#  0.9905007177235499,
#  0.9653803934813816,
#  0.9848855864223593,
#  0.9708688676855528,
#  0.9402600692392133,
#  0.8774803681499621,
#  0.8348391454867856,
#  0.8541332432660644,
#  0.7733682344000676,
#  0.7726927298826314,
#  0.8801401671873683,
#  0.8400743054969182,
# ...

# %%
# demonstrate prediction for next 30 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]

        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1


print(lst_output)
# Out:
# [0.941161]
# 101
# 1 day input [0.8866419  0.87431394 0.88431985 0.87836697 0.8986321  0.92582116
#  0.92877649 0.95676771 0.93869797 0.93304061 0.94950604 0.96424048
#  0.95512117 0.95989192 0.96635143 0.96246728 0.92295027 0.9598497
#  0.98792536 0.98594106 0.92531453 0.92172591 0.96474711 0.97572406
#  0.99159841 0.96972895 0.97614625 0.96795575 1.         0.99016297
#  0.99050072 0.96538039 0.98488559 0.97086887 0.94026007 0.87748037
#  0.83483915 0.85413324 0.77336823 0.77269273 0.88014017 0.84007431
#  0.89673225 0.85527316 0.83884995 0.74233725 0.82327113 0.78143207
#  0.6665963  0.7921557  0.64118044 0.68614371 0.66001013 0.65203074
#  0.58642236 0.56586169 0.66089673 0.65515494 0.70970193 0.66452757
#  0.69437642 0.69218104 0.63569197 0.65266402 0.63780292 0.7267162
#  0.71388162 0.74191506 0.75002111 0.77222832 0.83049059 0.8194292
#  0.8289707  0.8125475  0.78776492 0.75162543 0.78426074 0.77974331
#  0.81326522 0.8141096  0.79473106 0.83336148 0.85898843 0.83901883
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)
import matplotlib.pyplot as plt
len(df1)
# Out:
# 1258

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))

ax = plt.gca()
ax.set_facecolor('#f7f9fc')
ax.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)


plt.plot(
    day_new,
    scaler.inverse_transform(df1[1158:]),
    label='Actual Data',
    color='black',
    linewidth=2.5,
    markersize=5
)

plt.plot(
    day_pred,
    scaler.inverse_transform(lst_output),
    label='Predicted Data(30 days)',
    color='darkorange',
    linestyle='dashed',
    linewidth=2.5,
    markersize=6
)

plt.axvspan(day_new[0], day_new[-1], facecolor='lightblue', alpha=0.1, label='Actual Data Range')

plt.title('Actual vs Predicted Data(30 days)', fontsize=20, color='black', weight='bold')
plt.xlabel('Days', fontsize=16, weight='bold')
plt.ylabel('Scaled Values', fontsize=16, weight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(loc='lower right', fontsize=14, frameon=True, shadow=True, borderpad=1, facecolor='white')

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

df3 = df1.tolist()
df3.extend(lst_output)

plt.figure(figsize=(12, 8))

plt.plot(df3[1200:], color='black', linewidth=2, linestyle='-', alpha=0.8)

plt.title('Actual vs Predicted Data(30 days)', fontsize=22, color='#2c3e50', weight='bold', loc='center')
plt.xlabel('Days', fontsize=16, weight='bold', color='#34495e', labelpad=10)
plt.ylabel('Scaled Values', fontsize=16, weight='bold', color='#34495e', labelpad=10)

plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')

plt.grid(color='gray', linestyle='--', linewidth=0.6, alpha=0.5)

ax = plt.gca()
ax.set_facecolor('#f7f9fc')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

plt.show()
